# %% [markdown]
# #De Pseudocódigo a Lenguajes de Programación

# %% [markdown]
# ## ☣ Recordemos

# %% [markdown]
# 📝 Algoritmo
#
# **Algoritmo** es una secuencia finita de **instrucciones** bien definidas que, al ejecutarse, resuelven un problema o realizan una tarea específica.
# Los algoritmos son la base de toda programación, ya que definen la lógica que seguirá un programa para alcanzar su objetivo.
#
# 📝 Instrucciones
#
# Las instrucciones son **acciones** básicas que se pueden implementar de modo general en un algoritmo.
# Las **instrucciones o acciones** incluyen muchas veces **elementos o datos**, en informática se conocen como **variables**, que son como contenedores de información que luego será utilizada.📥
#
# 📝 Variables
#
# Una **variable** es un espacio en la memoria de la computadora que almacena datos que pueden cambiar durante la ejecución de un programa. Las variables tienen un **nombre** y un **tipo de dato** que determina el tipo de información que pueden almacenar.
#
# Mientras que en seudocódigo de **PSeInt** las variables se declaraban así:
#
# Definir **(NombreVariable)** Como **(Tipo de Dato)**
#
# Ejemplo de PSeInt:
#
#     Definir edad Como Entero
#     Definir nombre Como Cadena

# %% [markdown]
# # ⏩ Lenguajes de Programación

# %% [markdown]
# ## Que es un Lenguaje de Programacion?
#
# Un lenguaje de programación es un **conjunto de reglas** e **instrucciones** que permiten a los programadores comunicarse con una computadora. Los programadores usan estos lenguajes para crear programas y aplicaciones.
#
# Diferencia entre Algoritmo y un Programa
# Un **algoritmo** es un conjunto de pasos organizados de manera lógica para resolver un problema o realizar una tarea.
#
# Por otro lado, un **programa** es la implementación de un algoritmo en un **lenguaje de programación** para que una computadora pueda ejecutarlo. Es decir, el algoritmo es la idea y el programa es la versión escrita en un lenguaje que la computadora entiende (como Python, C++, Java, etc.).

# %% [markdown]
# ## Lenguaje máquina vs. lenguaje de alto nivel
# El lenguaje de máquina, también conocido como código máquina, es el lenguaje más básico que una computadora puede entender. Consiste en una serie de números binarios (ceros y unos) que representan instrucciones directamente ejecutables por el hardware. Es el lenguaje en el que se traducen todos los demás lenguajes de programación para que la computadora pueda llevar a cabo las tareas.
# Características principales:
#
# * Nivel más bajo:
# Es el nivel más cercano al hardware de la computadora.
# * Código binario:
# Está compuesto exclusivamente por ceros y unos, que representan instrucciones y datos.
# * Específico de la arquitectura:
# El lenguaje máquina es diferente para cada tipo de procesador o arquitectura de computadora.
# * Difícil de entender para humanos:
# Es muy difícil de leer y escribir directamente por los humanos, ya que no es intuitivo.
# * Base de la programación:
# Es el lenguaje fundamental en el que se basan todos los demás lenguajes de programación.
#
# ### ¿Cómo funciona?
# Un programa escrito en un lenguaje de alto nivel (como Python, Java, etc.) debe ser traducido al lenguaje máquina para que la computadora pueda ejecutarlo. Este proceso de traducción se realiza mediante **compiladores o intérpretes**. Una vez traducido, el código máquina se carga en la memoria de la computadora y el procesador lo ejecuta.
#
# Ejemplos de instrucciones en lenguaje máquina:
# * Instrucciones de transferencia de datos: Mover datos de una ubicación a otra en la memoria.
# * Instrucciones aritméticas: Sumar, restar, multiplicar o dividir datos.
# * Instrucciones de control: Tomar decisiones basadas en ciertas condiciones (saltos, bucles).
#
# En resumen, el lenguaje máquina es el lenguaje nativo de las computadoras, fundamental para su funcionamiento, aunque su uso directo por parte de los humanos es limitado debido a su complejidad.
#
# Ejemplos de Lenguajes de Bajo Nivel:
# 1. Lenguaje ensamblador: Es un lenguaje simbólico que representa las instrucciones del código máquina de una manera más legible para los humanos. Cada arquitectura de procesador tiene su propio lenguaje ensamblador.
# Por ejemplo, el lenguaje ensamblador x86 se utiliza en procesadores Intel y compatibles, mientras que el ensamblador MIPS se utiliza en sistemas MIPS.
# Otros ejemplos de lenguajes de bajo nivel:
# 2. Lenguajes HDL (Hardware Description Languages):
# Se utilizan para describir el diseño de circuitos electrónicos y hardware, como procesadores y chips.
# 3. Ensamblador ARM:
# Es popular en sistemas embebidos, dispositivos móviles y sistemas basados en Linux, con una arquitectura RISC que facilita la ejecución rápida de instrucciones

# %% [markdown]
# ## Lenguajes de Programación Compilados o Interpretados
#
# * Compilados: Se traduce todo el codigo a lenguaje de maquina antes de ejecutarlo.
# * Interpretados: Se traduce a lenguaje de maquina a medida que se va ejecutando el codigo.
#
# Los lenguajes de programación **compilados y los interpretados** se diferencian en cómo se ejecuta el código. Los compilados son más rápidos y eficientes, pero los interpretados son más flexibles.
#
# Los compiladores y los intérpretes son programas que convierten el código legible por humanos en código máquina legible por computadoras.
#
# Los lenguajes interpretados son fundamentales en el desarrollo web y otras áreas de la programación. Esto se debe a su flexibilidad, facilidad de uso y capacidad de adaptación a múltiples plataformas.
#
# <div
#     class="table-responsive"
# >
#     <table
#         class="table table-primary"
#     >
#         <thead>
#             <tr>
#                 <th scope="col"></th>
#                 <th scope="col">Compilado</th>
#                 <th scope="col">Interpretado</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr class="">
#                 <td scope="row">Cómo se ejecuta</td>
#                 <td>Se traduce todo el código a lenguaje de máquina antes de ejecutarlo</td>
#                 <td>Se traduce a lenguaje de máquina a medida que se ejecuta</td>
#             </tr>
#             <tr class="">
#                 <td scope="row">Ventajas</td>
#                 <td>Rendimiento superior y uso más eficiente de recursos</td>
#                 <td>Más flexible y tiempos de desarrollo más rápidos</td>
#             </tr>
#             <tr class="">
#                 <td scope="row">Desventajas</td>
#                 <td>Requiere recompilar el programa cada vez que se hace un cambio</td>
#                 <td>Requiere instalar el intérprete para ejecutar el programa</td>
#             </tr>
#             <tr class="">
#                 <td scope="row">Ejemplos</td>
#                 <td>C, C++, Java, Go, Rust</td>
#                 <td>Ruby, Python, JavaScript</td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %% [markdown]
# ## Sintaxis
#
# La sintaxis de un lenguaje de programación es el conjunto de reglas que determinan cómo se escribe el código. Es similar a las reglas gramaticales de un idioma.
# * La sintaxis es importante porque permite que el código sea legible para los programadores y las máquinas.
# * Cada lenguaje de programación tiene su propia sintaxis, aunque algunos comparten elementos comunes.
#
# ###Errores de sintaxis
# Si un programador no sigue la sintaxis correcta, el código puede tener errores de sintaxis. Estos errores impiden que el programa se compile o se ejecute.
# ###Herramientas para la sintaxis
# El resaltado de sintaxis, carateres de finalizacion de instrucciones y el estilo de sangría son herramientas que ayudan a los programadores a reconocer los elementos del código.
#
# Por Ejemplo en C++ y Java:
# El Final de linea lo determina un **";" (un punto y coma)**
# Y el Bloque de codigo (frases) comienzan y terminan con llaves **"{ }" (entre llaves)**
#
#   **C**
#
# ```
# #include <iostream>
# using namespace std;
#
# int main(void)
# {
#   printf("Hola, Mundo!\n");
#   return 0;
# }
# ```
#
#
# Y en el caso de Python no requiere carateres especiales de finalización de linea y los ploques de codigo los determina la sangria (obligatoria) y para escribir comentarios que no se van aejecutar se coloca el caracter especial **#**
#
# **Python**
#
# ```
# def saludar():
#   print("Hola, mundo!")
#
# ```
#
# Proba como se ejecuta hace click en  ▶

# %%
#Esto es un comentario

def saludar():
  print("Hola, mundo!")

saludar()
#Aca se ejecuta
# Out:
# Hola, mundo!

# %% [markdown]
# ## Tipado en los Lenguajes de Programación
#
# ### Fuertemente Tipado
# Un lenguaje fuertemente tipado es un lenguaje de programación que impone reglas estrictas sobre los tipos de datos y las operaciones entre variables. Estas reglas están diseñadas para evitar errores de programación.
#
# El compilador de un lenguaje fuertemente tipado:
# *	Detecta errores relacionados con tipos de variable incorrectos
# *	Prohíbe operaciones entre variables de distintos tipos
# *	Garantiza la conformidad con la tipificación de datos
#
# El tipado fuerte es recomendable porque:
#
# *	Exige castear o comprobar el tipo de cada variable
# *	Ayuda al programador a filtrar bugs relacionados a los tipos
# *	Es más seguro, porque no permite hacer operaciones con variable de distintos tipos.
#
# En contraste, un lenguaje débilmente tipado es más flexible y permite usar variables y valores sin especificar sus tipos. Por ejemplo, JavaScript es un lenguaje débilmente tipado.
#
# ### Débilmente Tipado
# Un lenguaje de programación débilmente tipado es aquel que no requiere especificar el tipo de cada variable. Esto permite asignar valores de distintos tipos a una misma variable, sin necesidad de realizar conversiones explícitas.
# Características
# *	Permiten cambiar de tipos de datos "al vuelo"
# *	Permiten usar y manipular variables y valores sin especificar sus tipos
# *	Pueden hacer que el código sea más conciso y sencillo
# *	Pueden mejorar la flexibilidad y creatividad
#
# Ejemplos JavaScript, PHP, Perl.
#
# ### Ventajas y desventajas
# Entre sus ventajas, se encuentran la posibilidad de reducir la cantidad de código que se debe escribir y mantener. Sin embargo, también pueden provocar comportamientos inesperados y dificultar la depuración.
#
# ### Cómo funcionan
# En los lenguajes débilmente tipados, el intérprete o compilador permite la coerción implícita, lo que significa que automáticamente convierte valores entre diferentes tipos de datos.

# %% [markdown]
# ## Variables y su sintaxis

# %% [markdown]
# ## Nombres de las Variables
# En Leguajes de Programación estructurados debemos tener algunas reglas de sintaxis en cuenta.
#
# Si se desea nombrar una variable, se deben seguir las siguientes reglas:
#
# **Nombres de Variables:**
# *   Se recomienda mas de 4 caracteres y menos de 20, salvo para contadores de uso temporal de 1 (un) carácter como i, j, n, x etc..
# *   El nombre de la variable debe de estar compuesto por MAYÚSCULAS, minúsculas, dígitos, y el carácter _ (guion bajo)
# *   El nombre de la variable debe comenzar con una letra;
# *   En la mayoría de los lenguajes el nombre de la variable NO puede empezar con un números o símbolo. (No se permite comenzar con 0-9 ni $, &, !)
# *   El carácter guion bajo es considerado una letra;
# *   No se permiten espacios
# *   Las mayúsculas y minúsculas se tratan de forma distinta. (distigue entre Mayuscula y minuscula)
# *   El nombre de las variables no puede ser igual a alguna de las palabras reservadas.
#
# <table > <tbody>
#         <tr>
#             <th>
#                 <div><span>Regla violada</span></div>
#             </th>
#             <th>
#                 <div><span>Nombre inválido</span></div>
#             </th>
#             <th>
#                 <div><span>Solución</span></div>
#             </th>
#         </tr>
#         <tr>
#             <td>
#                 <div><span>Empieza con número</span></div>
#             </td>
#             <td>
#                 <div><span>1variable</span></div>
#             </td>
#             <td>
#                 <div><span>variable1</span></div>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <div><span>Contiene espacio</span></div>
#             </td>
#             <td>
#                 <div><span>mi variable></span></div>
#             </td>
#             <td>
#                 <div><span>mi_variable></span></div>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <div><span>Contiene carácter especial</span></div>
#             </td>
#             <td>
#                 <div><span>mi!variable></span></div>
#             </td>
#             <td>
#                 <div><span>mi_variable></span></div>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <div><span>Usa palabra clave</span></div>
#             </td>
#             <td>
#                 <div><span>if</div>
#             </td>
#             <td>
#                 <div><span>mi_if<span></div>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <div><span>Mayúsculas y minúsculas</span></div>
#             </td>
#             <td>
#                 <div><span>Variable</span></div>
#             </td>
#             <td>
#                 <div><span>variable</span></div>
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 <div><span>No descriptivo</span></div>
#             </td>
#             <td>
#                 <div>x</span></div>
#             </td>
#             <td>
#                 <div><span>longitud_del_rectangulo</span></div>
#             </td>
#         </tr></tbody>
# </table>

# %% [markdown]
# ##CONVENCIONES
# 1. **snake_case** para nombres de variables:
# La convención más común para nombres de variables en Python es utilizar snake_case, donde las palabras se separan por guiones bajos y se escriben en minúsculas.
#
#   *Por ejemplo: mi_variable, precio_total. *
# 2. **lowerCamelCase** para nombres de métodos:
# Aunque menos común para variables, lowerCamelCase (donde la primera letra de cada palabra, excepto la primera, es mayúscula) se utiliza para nombrar métodos.
#   *Por ejemplo: miVariable, precioTotal. *
#
# 3. Nombres descriptivos:
# Los nombres de las variables deben ser lo más descriptivos posible para que el código sea fácil de entender.
#
# 4. Evitar nombres de una sola letra:
# Excepto en casos específicos como contadores de bucles, se recomienda evitar nombres de variables de una sola letra, como x, y, etc.
#
# 5. Constantes en mayúsculas:
# Para variables que se consideran constantes (es decir, que no deberían cambiar), se utiliza la convención SNAKE_CASE (todo en mayúsculas y separado por guiones bajos).
#
#   *Por ejemplo: PI, GRAVEDAD, COLOR_BK*

# %% [markdown]
# ##Tipos de Datos
# Los tipos de datos definen la naturaleza de los datos que una variable puede almacenar.
#
# <div><div>
#         <div>
#             <span>Python tiene varios tipos de datos, entre ellos numéricos, secuencias, binarios, booleanos, de
#                 conjuntos, de diccionarios y de tipos especializados.</span>
#         </div>
#         <div>
#             <table>
#                 <tbody>
#                     <tr>
#                         <th>
#                             <div><span><span>Tipo de dato</span></div>
#                         </th>
#                         <th>
#                             <div><span>Descripción</span></div>
#                         </th>
#                     </tr>
#                     <tr>
#                         <td>
#                             <div><span>Numérico</span></div>
#                         </td>
#                         <td>
#                             <div><span><span>int, float,complex</span></div>
#                         </td>
#                     </tr>
#                     <tr>
#                         <td>
#                             <div><span>Cadena</span></div>
#                         </td>
#                         <td>
#                             <div><span>str, para almacenar caracteres alfanuméricos</span></div>
#                         </td>
#                     </tr>
#                     <tr>
#                         <td>
#                             <div><span>Secuencia</span></div>
#                         </td>
#                         <td>
#                             <div><span>list, tuple, range, para almacenar una secuencia de datos</span></div>
#                         </td>
#                     </tr>
#                     <tr>
#                         <td>
#                             <div><span>Binario</span></div>
#                         </td>
#                         <td>
#                             <div><span>bytes, bytearray, memoryview,para almacenar datos binarios</span></div>
#                         </td>
#                     </tr>
#                     <tr>
#                         <td>
#                             <div><span>Booleano</span></div>
#                         </td>
#                         <td>
#                             <div><span><span>bool, para almacenar valores True (Verdadero) o False (Falso)</span></div>
#                         </td>
#                     </tr>
#                     <tr>
#                         <td>
#                             <div><span>Conjunto</span></div>
#                         </td>
#                         <td>
#                             <div><span></span><span>set, frozenset, para trabajar con una lista de elementos
#                                     únicos</span></div>
#                         </td>
#                     </tr>
#                     <tr>
#                         <td>
#                             <div><span>Diccionario</span></div>
#                         </td>
#                         <td>
#                             <div><span><span>dict, para mapear valores</span></div>
#                         </td>
#                     </tr>
#                     <tr>
#                         <td>
#                             <div><span>Especializado</span></div>
#                         </td>
#                         <td>
#                             <div><span>Fechas y horas, matrices, colas, enumeraciones</span></div>
#                         </td>
#                     </tr>
#                 </tbody>
#             </table>
#         </div>
#         <div>
#             <div>
#                 <div>
#                     <span><span>Para obtener el tipo de una variable en Python, puedes usar la función incorporada
#                             type().</span>
#                 </div>
#             </div>
#         </div>
#         <div>
#             <div>
#                 <div> <span><span>Los tipos de datos tienen características y propiedades específicas que los hacen
#                             adecuados para ciertos usos y operaciones.</span><span> Por ejemplo, los números enteros se
#                             almacenan como secuencias de bits en la memoria.</span><span>Las listas son mutables, es
#                             decir, se pueden modificar, mientras que las tuplas son inmutables.</span> </div>
#             </div>
#         </div>
# </div>
# </div>

# %%
nombre = "Leonel Messi" #declaracion de variable cadena
edad = 38               #declaracion de variable entera
numero = int("34")      #Comentario

print(type(nombre))  # deberia mostrar 'str'
print(type(edad))   # deberia mostrar 'int'
print(type(numero))   # deberia mostrar 'int'
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# #Estructuras Secuenciales

# %% [markdown]
# ⚛ Recordemos
# Las instrucciones secuenciales en pseudocodigo en PSeInt eran las instrucciones simples de :
# ###Asignacion
# ```
# # Era cuando le asignabamos un valor a una variable
# N <- 0
# N <- N + 1
# nombre <- "Leonel"
# superficie <- (base * altura)/2
# ```

# %%
#En Python
N = 0
N = N + 1
nombre = "Leonel"
base = 10
altura = 20
superficie = (base * altura)/2

# %% [markdown]
# ### Leer variable1 , variable2 , ... ,variableN
# ```
# # Tomabamos un valor que ingresaba el usuario
# Leer N
# Leer apellido
# Leer nombre
# ```

# %%
#En Python
N = input("Ingrese un numero: ")
apellido = input("Ingrese su apellido: ")
nombre = input("Ingrese su nombre: ")
# Out:
# Ingrese un numero10
# Ingrese su apellidoMessi
# Ingrese su nombreLeonel

# %% [markdown]
# ###Escribir (se puede usar Imprimir y Mostrar en lugar de Escribir)
# ```
# # Cuando Mostrabamos un mensaje al usuario
# Escribir "Ingrese un numero"
# Escribir "La superficie del Triangulo es", superficie
# Mostrar Sin Saltar "Bienvenido Sr. " , nombre , " ", apellido
# Mostrar nombre
# ```

# %%
#En Python
print("Ingrese un numero")
print("La superficie del Triangulo es", superficie)
print('Bienvenido Sr. {nom} , {ape}'.format(nom=nombre, ape=apellido))
# Out:
# Ingrese un numero
# La superficie del Triangulo es 100.0
# Bienvenido Sr. Leonel , Messi

# %% [markdown]
# ---
#
# Hemos visto la equivalencia de las instrucciones secuenciales de PSeInt en Python
#
#     Asignar: N <- 1  // en Pyton es : N=1
#     Mostrar mensaje : Escribir "Bienvenido" En Python print("Bienvenido")
#     Ingresar: Leer nombre en Python es nombre = input("Ingrese nombre")
#
# Ahora te toca a vos escribi instrucciones de Asignacion, Escritura y Lectura en Lenguaje Python luego presiona ▶ para ver el resultado:

# %%
#Aqui escribi el codigo en Python ()

# %%
# @title Escribi las instrucciones equivalesnte a Asignar, Leer y Escribir en lenguaje Python

# %% [markdown]
# # Estructuras de Control en Python

# %% [markdown]
# # Condicionales

# %% [markdown]
# ## Condicional IF - ELSE (SI - SINO)

# %% [markdown]
# ### En Diagrama de Flujo
#
# ![Imagen_if.png](data:image/png;base64,...)

# %% [markdown]
# ###♻
# ###En PSeInt :
#     Algoritmo votar
#     Escribir "Ingrese su edad:"
#     Leer edad
#     Si edad >= 18 Entonces
#         Escribir "Puedes votar."
#     Sino
#         Escribir "No puedes votar."
#     FinSi
#     FinAlgoritmo

# %% [markdown]
# ###En Python

# %%
nombre = str #declaracion de variable cadena
nombre = input("Ingrese su nombre: ")
edad = int(input("Ingrese su edad: ")) #declaracion de variable entera y asignacion

if edad >= 18:
    print(nombre , "Puedes votar.")
else:
    print(nombre , "No puedes votar.")

# %% [markdown]
# ##Condicional IF anidado

# %% [markdown]
# **Ejemplo:** Determinar el tipo de clima según la temperatura.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###En PSeInt
#
#     Algoritmo Temperatura
#     Escribir "Ingrese la temperatura: "
#     Leer temperatura
#
#     Si temperatura > 30 Entonces
#         Escribir "Hace mucho calor."
#     Sino
#         Si temperatura >= 20 Entonces
#             Escribir "El clima es agradable."
#         Sino
#             Escribir "Hace frío."
#         FinSi
#     FinSi
#     FinAlgoritmo

# %% [markdown]
# ### En Python

# %%
temperatura = int
temperatura = input("Ingrese la temperatura: ")
if temperatura > 30:
    print("Hace mucho calor.")
elif temperatura >= 20:
    print("El clima es agradable.")
else:
    print("Hace frío.")

# %% [markdown]
# ## Condicional CASE (SEGÚN – SWITCH-CASE / MATCH-CASE)

# %% [markdown]
# **Ejemplo**: Selección de un menú de bebidas.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### En PSeInt
#     Algoritmo Menu
#     Escribir "Seleccione una opción:"
#     Escribir "1. Café negro"
#     Escribir "2. Café con leche"
#     Escribir "3. Té"
#     Leer opcion
#
#     Según opcion Hacer
#         1: Escribir "Usted eligió Café negro."
#         2: Escribir "Usted eligió Café con leche."
#         3: Escribir "Usted eligió Té."
#         De Otro Modo:
#             Escribir "Opción no válida."
#     FinSegún
#     Fin Algoritmo

# %% [markdown]
# ### En Python

# %%
opcion = int(input("Seleccione una opción:\n1. Café negro\n2. Café con leche\n3. Té\n"))

match opcion:
    case 1:
        print("Usted eligió Café negro.")
    case 2:
        print("Usted eligió Café con leche.")
    case 3:
        print("Usted eligió Té.")
    case _:
        print("Opción no válida.")

# %% [markdown]
# ### Informacion Adicional

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# En Python, match-case funciona como switch, pero solo desde la versión 3.10. Para versiones anteriores, se usaría if-elif-else.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ###Comparación rápida de sintaxis en los tres lenguajes
#
# <div class=WordSection1>
#
# <table class=MsoTable15Plain3 border=0 cellspacing=0 cellpadding=0 width=616
#  style='width:461.75pt;border-collapse:collapse;mso-yfti-tbllook:1184;
#  mso-padding-alt:0cm 5.4pt 0cm 5.4pt'>
#  <tr style='mso-yfti-irow:-1;mso-yfti-firstrow:yes;mso-yfti-lastfirstrow:yes'>
#   <td valign=top style='border:none;border-bottom:solid #7F7F7F 1.0pt;
#   mso-border-bottom-themecolor:text1;mso-border-bottom-themetint:128;
#   mso-border-bottom-alt:solid #7F7F7F .5pt;mso-border-bottom-themecolor:text1;
#   mso-border-bottom-themetint:128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   517'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>Condición<o:p></o:p></span></b></p>
#   </td>
#   <td width=154 valign=top style='width:115.7pt;border:none;border-bottom:solid #7F7F7F 1.0pt;
#   mso-border-bottom-themecolor:text1;mso-border-bottom-themetint:128;
#   mso-border-bottom-alt:solid #7F7F7F .5pt;mso-border-bottom-themecolor:text1;
#   mso-border-bottom-themetint:128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   1'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>PSeInt<o:p></o:p></span></b></p>
#   </td>
#   <td width=208 valign=top style='width:155.95pt;border:none;border-bottom:
#   solid #7F7F7F 1.0pt;mso-border-bottom-themecolor:text1;mso-border-bottom-themetint:
#   128;mso-border-bottom-alt:solid #7F7F7F .5pt;mso-border-bottom-themecolor:
#   text1;mso-border-bottom-themetint:128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   1'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>C++<o:p></o:p></span></b></p>
#   </td>
#   <td valign=top style='border:none;border-bottom:solid #7F7F7F 1.0pt;
#   mso-border-bottom-themecolor:text1;mso-border-bottom-themetint:128;
#   mso-border-bottom-alt:solid #7F7F7F .5pt;mso-border-bottom-themecolor:text1;
#   mso-border-bottom-themetint:128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   1'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>Python<o:p></o:p></span></b></p>
#   </td>
#  </tr>
#  <tr style='mso-yfti-irow:0'>
#   <td valign=top style='border:none;border-right:solid #7F7F7F 1.0pt;
#   mso-border-right-themecolor:text1;mso-border-right-themetint:128;mso-border-right-alt:
#   solid #7F7F7F .5pt;mso-border-right-themecolor:text1;mso-border-right-themetint:
#   128;background:#F2F2F2;mso-background-themecolor:background1;mso-background-themeshade:
#   242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   68'><b><span lang=es-419 style='color:black;mso-color-alt:windowtext;
#   text-transform:uppercase;mso-ansi-language:#580A'>IF-SINO</span></b><b><span
#   lang=es-419 style='text-transform:uppercase;mso-ansi-language:#580A'><o:p></o:p></span></b></p>
#   </td>
#   <td width=154 valign=top style='width:115.7pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   64'><span lang=es-419 style='color:black;mso-color-alt:windowtext;mso-ansi-language:
#   #580A'>Si ... Entonces</span><span lang=es-419 style='mso-ansi-language:#580A'><o:p></o:p></span></p>
#   </td>
#   <td width=208 valign=top style='width:155.95pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   64'><span class=SpellE><span lang=es-419 style='color:black;mso-color-alt:
#   windowtext;mso-ansi-language:#580A'>if</span></span><span lang=es-419
#   style='color:black;mso-color-alt:windowtext;mso-ansi-language:#580A'> (...) <span
#   class=GramE>{ }</span> <span class=SpellE>else</span> <span class=GramE>{ }</span></span><span
#   lang=es-419 style='mso-ansi-language:#580A'><o:p></o:p></span></p>
#   </td>
#   <td valign=top style='background:#F2F2F2;mso-background-themecolor:background1;
#   mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   64'><span class=SpellE><span lang=es-419 style='color:black;mso-color-alt:
#   windowtext;mso-ansi-language:#580A'>if</span></span><span lang=es-419
#   style='color:black;mso-color-alt:windowtext;mso-ansi-language:#580A'> <span
#   class=GramE>... :</span> <span class=SpellE>else</span>:</span><span
#   lang=es-419 style='mso-ansi-language:#580A'><o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style='mso-yfti-irow:1'>
#   <td valign=top style='border:none;border-right:solid #7F7F7F 1.0pt;
#   mso-border-right-themecolor:text1;mso-border-right-themetint:128;mso-border-right-alt:
#   solid #7F7F7F .5pt;mso-border-right-themecolor:text1;mso-border-right-themetint:
#   128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   4'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>IF anidado<o:p></o:p></span></b></p>
#   </td>
#   <td width=154 valign=top style='width:115.7pt;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%'><span
#   lang=es-419 style='mso-ansi-language:#580A'>Si ... Entonces Si ... Entonces
#   ... <span class=SpellE>FinSi</span><o:p></o:p></span></p>
#   </td>
#   <td width=208 valign=top style='width:155.95pt;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%'><span
#   class=SpellE><span lang=es-419 style='mso-ansi-language:#580A'>if</span></span><span
#   lang=es-419 style='mso-ansi-language:#580A'> (...) <span class=GramE>{ }</span>
#   <span class=SpellE>else</span> <span class=SpellE>if</span> (...) <span
#   class=GramE>{ }</span> <span class=SpellE>else</span> <span class=GramE>{ }</span><o:p></o:p></span></p>
#   </td>
#   <td valign=top style='padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%'><span
#   class=SpellE><span lang=es-419 style='mso-ansi-language:#580A'>if</span></span><span
#   lang=es-419 style='mso-ansi-language:#580A'> <span class=GramE>... :</span> <span
#   class=SpellE>elif</span> <span class=GramE>... :</span> <span class=SpellE>else</span>:<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style='mso-yfti-irow:2;mso-yfti-lastrow:yes'>
#   <td valign=top style='border:none;border-right:solid #7F7F7F 1.0pt;
#   mso-border-right-themecolor:text1;mso-border-right-themetint:128;mso-border-right-alt:
#   solid #7F7F7F .5pt;mso-border-right-themecolor:text1;mso-border-right-themetint:
#   128;background:#F2F2F2;mso-background-themecolor:background1;mso-background-themeshade:
#   242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   68'><b><span lang=es-419 style='color:black;mso-color-alt:windowtext;
#   text-transform:uppercase;mso-ansi-language:#580A'>CASE/SWITCH</span></b><b><span
#   lang=es-419 style='text-transform:uppercase;mso-ansi-language:#580A'><o:p></o:p></span></b></p>
#   </td>
#   <td width=154 valign=top style='width:115.7pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   64'><span lang=es-419 style='color:black;mso-color-alt:windowtext;mso-ansi-language:
#   #580A'>Según ... Hacer</span><span lang=es-419 style='mso-ansi-language:#580A'><o:p></o:p></span></p>
#   </td>
#   <td width=208 valign=top style='width:155.95pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   64'><span lang=es-419 style='color:black;mso-color-alt:windowtext;mso-ansi-language:
#   #580A'>switch(...) <span class=GramE>{ case</span> ... break<span
#   class=GramE>; }</span></span><span lang=es-419 style='mso-ansi-language:#580A'><o:p></o:p></span></p>
#   </td>
#   <td valign=top style='background:#F2F2F2;mso-background-themecolor:background1;
#   mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:8.0pt;line-height:115%;mso-yfti-cnfc:
#   64'><span lang=es-419 style='color:black;mso-color-alt:windowtext;mso-ansi-language:
#   #580A'>match ... case</span><span lang=es-419 style='mso-ansi-language:#580A'><o:p></o:p></span></p>
#   </td>
#  </tr>
# </table>
#
# <p class=MsoNormal><o:p>&nbsp;</o:p></p>
#
# </div>

# %% [markdown]
# # Repetitivas

# %% [markdown]
# ## Repetir Mientras (WHILE)

# %% [markdown]
# Se usa cuando no sabemos cuántas veces se repetirá y la condición se evalúa al principio.
#
# **Ejemplo**: Pedir una clave hasta que sea la correcta (1234).

# %% [markdown]
# ### DFD

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### En PSeInt

# %% [markdown]
#     Algoritmo IngresoSistema
#       Escribir "Ingrese la clave:"
#       Leer clave
#     Mientras clave <> "1234" Hacer
#       Escribir "Clave incorrecta. Intente nuevamente:"
#       Leer clave
#     FinMientras
#      Escribir "¡Clave correcta!"
#     Fin Algoritmo

# %% [markdown]
# ### En Python

# %%
clave = input("Ingrese la clave: ")

while clave != "1234":
    clave = input("Clave incorrecta. Intente nuevamente: ")

print("¡Clave correcta!")

# %% [markdown]
# ## Repetir Hasta Que (DO - WHILE)

# %% [markdown]
# Se usa cuando queremos que el bloque se ejecute al menos una vez, y la condición se evalúe al final.
#
# En Python y C++ no existe como estructura directa, pero se simula.
#
# **Ejemplo**: Pedir texto hasta que el usuario escriba "salir".

# %% [markdown]
# ### DFD

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### En PSeInt

# %% [markdown]
#     Repetir
#       Escribir "Escriba algo (o 'salir' para terminar):"
#       Leer texto
#     Hasta Que texto = "salir"

# %% [markdown]
# ### En Python

# %%
texto = str

while texto != "salir":
    texto = input("Escriba algo (o 'salir' para terminar): ")

# %% [markdown]
# ## Repetir Hasta Que (DO - WHILE)

# %% [markdown]
# Se usa cuando queremos que el bloque se ejecute al menos una vez, y la condición se evalúe al final.
#
# ![image.png](data:image/png;base64,...)
# En Python y C++ no existe como estructura directa, pero se simula.
#
# Ejemplo: Pedir texto hasta que el usuario escriba "salir".

# %% [markdown]
# ### DFD

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### PSeInt

# %% [markdown]
#     Algoritmo Primeros5
#     Para i <- 1 Hasta 5 Con Paso 1 Hacer
#         Escribir "Número: ", i
#     FinPara
#     Fin Algoritmo

# %% [markdown]
# ### En Python

# %%
for i in range(1, 6):  # range va de 1 a 5 (6 no se incluye)
    print("Número:", i)

# %% [markdown]
# ### Informacion Adicional

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# <p class=MsoNormal><b><span lang=es-419 style='mso-ansi-language:#580A'>Cuadro
# resumen comparativo:<o:p></o:p></span></b></p>
#
# <table class=MsoTable15Plain3 border=0 cellspacing=0 cellpadding=0
#  style='border-collapse:collapse;mso-yfti-tbllook:1184;mso-padding-alt:0cm 5.4pt 0cm 5.4pt'>
#  <tr style='mso-yfti-irow:-1;mso-yfti-firstrow:yes;mso-yfti-lastfirstrow:yes'>
#   <td width=132 valign=top style='width:99.25pt;border:none;border-bottom:solid #7F7F7F 1.0pt;
#   mso-border-bottom-themecolor:text1;mso-border-bottom-themetint:128;
#   mso-border-bottom-alt:solid #7F7F7F .5pt;mso-border-bottom-themecolor:text1;
#   mso-border-bottom-themetint:128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   517'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>Estructura<o:p></o:p></span></b></p>
#   </td>
#   <td width=180 valign=top style='width:135.05pt;border:none;border-bottom:
#   solid #7F7F7F 1.0pt;mso-border-bottom-themecolor:text1;mso-border-bottom-themetint:
#   128;mso-border-bottom-alt:solid #7F7F7F .5pt;mso-border-bottom-themecolor:
#   text1;mso-border-bottom-themetint:128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   1'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>PSeInt<o:p></o:p></span></b></p>
#   </td>
#   <td width=141 valign=top style='width:105.9pt;border:none;border-bottom:solid #7F7F7F 1.0pt;
#   mso-border-bottom-themecolor:text1;mso-border-bottom-themetint:128;
#   mso-border-bottom-alt:solid #7F7F7F .5pt;mso-border-bottom-themecolor:text1;
#   mso-border-bottom-themetint:128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   1'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>C++<o:p></o:p></span></b></p>
#   </td>
#   <td width=161 valign=top style='width:120.5pt;border:none;border-bottom:solid #7F7F7F 1.0pt;
#   mso-border-bottom-themecolor:text1;mso-border-bottom-themetint:128;
#   mso-border-bottom-alt:solid #7F7F7F .5pt;mso-border-bottom-themecolor:text1;
#   mso-border-bottom-themetint:128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   1'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>Python<o:p></o:p></span></b></p>
#   </td>
#  </tr>
#  <tr style='mso-yfti-irow:0'>
#   <td width=132 valign=top style='width:99.25pt;border:none;border-right:solid #7F7F7F 1.0pt;
#   mso-border-right-themecolor:text1;mso-border-right-themetint:128;mso-border-right-alt:
#   solid #7F7F7F .5pt;mso-border-right-themecolor:text1;mso-border-right-themetint:
#   128;background:#F2F2F2;mso-background-themecolor:background1;mso-background-themeshade:
#   242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   68'><b><span lang=es-419 style='color:black;mso-color-alt:windowtext;
#   text-transform:uppercase;mso-ansi-language:#580A'>Mientras</span></b><b><span
#   lang=es-419 style='text-transform:uppercase;mso-ansi-language:#580A'><o:p></o:p></span></b></p>
#   </td>
#   <td width=180 valign=top style='width:135.05pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   64'><span lang=es-419 style='color:black;mso-color-alt:windowtext;mso-ansi-language:
#   #580A'>Mientras ... Hacer</span><span lang=es-419 style='mso-ansi-language:
#   #580A'><o:p></o:p></span></p>
#   </td>
#   <td width=141 valign=top style='width:105.9pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   64'><span class=SpellE><span lang=es-419 style='color:black;mso-color-alt:
#   windowtext;mso-ansi-language:#580A'>while</span></span><span lang=es-419
#   style='color:black;mso-color-alt:windowtext;mso-ansi-language:#580A'> (...)
#   {}</span><span lang=es-419 style='mso-ansi-language:#580A'><o:p></o:p></span></p>
#   </td>
#   <td width=161 valign=top style='width:120.5pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   64'><span class=SpellE><span lang=es-419 style='color:black;mso-color-alt:
#   windowtext;mso-ansi-language:#580A'>while</span></span><span lang=es-419
#   style='color:black;mso-color-alt:windowtext;mso-ansi-language:#580A'> ...:</span><span
#   lang=es-419 style='mso-ansi-language:#580A'><o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style='mso-yfti-irow:1'>
#   <td width=132 valign=top style='width:99.25pt;border:none;border-right:solid #7F7F7F 1.0pt;
#   mso-border-right-themecolor:text1;mso-border-right-themetint:128;mso-border-right-alt:
#   solid #7F7F7F .5pt;mso-border-right-themecolor:text1;mso-border-right-themetint:
#   128;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   4'><b><span lang=es-419 style='text-transform:uppercase;mso-ansi-language:
#   #580A'>Repetir Hasta Que<o:p></o:p></span></b></p>
#   </td>
#   <td width=180 valign=top style='width:135.05pt;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal'><span
#   lang=es-419 style='mso-ansi-language:#580A'>Repetir ... Hasta Que<o:p></o:p></span></p>
#   </td>
#   <td width=141 valign=top style='width:105.9pt;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal'><span
#   lang=es-419 style='mso-ansi-language:#580A'>do <span class=GramE>{ ...</span>
#   } <span class=SpellE>while</span> (...);<o:p></o:p></span></p>
#   </td>
#   <td width=161 valign=top style='width:120.5pt;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal'><span
#   class=SpellE><span lang=es-419 style='mso-ansi-language:#580A'>while</span></span><span
#   lang=es-419 style='mso-ansi-language:#580A'> <span class=SpellE>not</span>
#   ...: <i>(simulado)</i><o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style='mso-yfti-irow:2;mso-yfti-lastrow:yes'>
#   <td width=132 valign=top style='width:99.25pt;border:none;border-right:solid #7F7F7F 1.0pt;
#   mso-border-right-themecolor:text1;mso-border-right-themetint:128;mso-border-right-alt:
#   solid #7F7F7F .5pt;mso-border-right-themecolor:text1;mso-border-right-themetint:
#   128;background:#F2F2F2;mso-background-themecolor:background1;mso-background-themeshade:
#   242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   68'><b><span lang=es-419 style='color:black;mso-color-alt:windowtext;
#   text-transform:uppercase;mso-ansi-language:#580A'>Para</span></b><b><span
#   lang=es-419 style='text-transform:uppercase;mso-ansi-language:#580A'><o:p></o:p></span></b></p>
#   </td>
#   <td width=180 valign=top style='width:135.05pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   64'><span lang=es-419 style='color:black;mso-color-alt:windowtext;mso-ansi-language:
#   #580A'>Para i &lt;- ...</span><span lang=es-419 style='mso-ansi-language:
#   #580A'><o:p></o:p></span></p>
#   </td>
#   <td width=141 valign=top style='width:105.9pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   64'><span class=SpellE><span lang=es-419 style='color:black;mso-color-alt:
#   windowtext;mso-ansi-language:#580A'>for</span></span><span lang=es-419
#   style='color:black;mso-color-alt:windowtext;mso-ansi-language:#580A'> (<span
#   class=SpellE>int</span> i=...; ...)</span><span lang=es-419 style='mso-ansi-language:
#   #580A'><o:p></o:p></span></p>
#   </td>
#   <td width=161 valign=top style='width:120.5pt;background:#F2F2F2;mso-background-themecolor:
#   background1;mso-background-themeshade:242;padding:0cm 5.4pt 0cm 5.4pt'>
#   <p class=MsoNormal style='margin-bottom:0cm;line-height:normal;mso-yfti-cnfc:
#   64'><span class=SpellE><span lang=es-419 style='color:black;mso-color-alt:
#   windowtext;mso-ansi-language:#580A'>for</span></span><span lang=es-419
#   style='color:black;mso-color-alt:windowtext;mso-ansi-language:#580A'> i in <span
#   class=SpellE>range</span>(...)</span><span lang=es-419 style='mso-ansi-language:
#   #580A'><o:p></o:p></span></p>
#   </td>
#  </tr>
# </table>
